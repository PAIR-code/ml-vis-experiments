# %% [markdown]
# How can we visualize saliency across an entire paragraph?
#
#
# This notebooks has rifts on [ecco](https://github.com/jalammar/ecco) visualizations, using gpt2 and gradient x input saliency.
#
# (I'd be interested in trying a T5 Q&A or summerization model with the [LIT API](https://github.com/PAIR-code/lit/blob/main/documentation/python_api.md) along with other saliency methods but haven't figured out how to hook everything up yet).

# %% [markdown]
# # Setup

# %%
# %%capture

# !pip install ecco
# !pip install sentencepiece

import ecco
lm = ecco.from_pretrained('gpt2', verbose=False)

# %%
def outputToSaliency(output, attr_method='grad_x_input'):
  position = output.n_input_tokens

  importance_id = position - output.n_input_tokens
  tokens = []
  attribution = output.attribution[attr_method]
  for idx, token in enumerate(output.tokens[0]):
    type = "input" if idx < output.n_input_tokens else 'output'
    if idx < len(attribution[importance_id]):
      imp = attribution[importance_id][idx]
    else:
      imp = 0

    tokens.append({
      'token': token,
      'token_id': int(output.token_ids[0][idx]),
      'type': type,
      'value': str(imp),  # because json complains of floats
      'position': idx
    })

  return {
    'tokens': tokens,
    'attributions': [att.tolist() for att in attribution]
  }

# %%
import IPython
import google.colab

def jsViz(data, settings={}):
  url = 'https://roadtolarissa.com/colab/fpld4dp8lo/2021-07-saliency-viz/paragraph-minimap/watch-files.js?6'
  
  if ('type' in settings):
    url = url.replace('paragraph-minimap', settings['type'])

  HTML_TEMPLATE = '''
    <link rel='stylesheet' href='__hs_placeholder'>
    <script src='https://pair.withgoogle.com/explorables/third_party/d3_.js'></script>
    <script src='https://pair.withgoogle.com/explorables/third_party/d3-scale-chromatic.v1.min.js'></script>
    <a style='display:none' class='no-js' href='{url}'>Click to authenticate</a>
    <div class='container'></div>

    <script>window.python_data = {data}</script>
    <script>window.python_settings = {settings}</script>
    <script>window.timeoutMS = 250</script>
    <script src='{url}'></script>
  '''

  IPython.display.display(IPython.display.HTML(HTML_TEMPLATE.format(
      data=data, 
      settings=settings, 
      url=url)
  ))

# %%
from IPython.display import Javascript
def resize_colab_cell():
  display(Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'))
get_ipython().events.register('pre_run_cell', resize_colab_cell)

# %% [markdown]
# # Charts

# %% [markdown]
# With longer input passages, text saliency visualizations typically only let us look a single output token's attributions at once:

# %%
text="""The race to Mars involves competition between manufacturers and nations. NASA has demurred in a potential rivalry with SpaceX or other manufacturers in any possible race to be first to Mars. It instead sees synergies in possible cooperation with such entities.  Boeing has stated that one of its rockets will lead to the first crewed expedition to Mars, before SpaceX or others will land a crewed mission. Boeing is the primary contractor on the U.S. Space Launch System (SLS) NASA rocket program that has the ultimate goal of a crewed Mars mission. SpaceX has declined to state that it is a race, or that it needs to race Boeing. Blue Origin has stated that with its New Armstrong and New Glenn rockets, it may be attempting missions to Mars, head-to-head with SpaceX's Interplanetary Transport System. This may result in commercial competition going to Mars. The first organization to land on Mars will be"""
output = lm.generate(text, generate=30, do_sample=True)
output.saliency()
# Out:
# <html lang="en">
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
#     var ecco_url = 'https://storage.googleapis.com/ml-intro/ecco/'
#     // var ecco_url = 'http://localhost:8000/ecco/'
#
#     if (window.ecco === undefined) window.ecco = {}
#
#     requirejs.config({
#         urlArgs: "bust=" + (new Date()).getTime(),
#         nodeRequire: require,
#         paths: {
#             d3: "https://d3js.org/d3.v5.min",
#             "d3-array": "https://d3js.org/d3-array.v2.min",
#             jquery: "https://code.jquery.com/jquery-3.5.1.min",
#             // oldEcco: ecco_url + 'ecco',
#             ecco: ecco_url + 'js/0.0.4/ecco-bundle.min',
#             xregexp: 'https://cdnjs.cloudflare.com/ajax/libs/xregexp/3.2.0/xregexp-all.min'
#         }
#     });
#     requirejs(['d3'],
#         function (d3) {
#             d3.select('#css').attr('href', ecco_url + 'html/styles.css')
#         })
#
#     console.log('Ecco initialize.')
# </script>
#
# <head>
#     <link id='css' rel="stylesheet" type="text/css">
# </head>
# <script>
#     // console.log('defining basic')
#     define('basic', ['d3'],
#         function (d3) {
#             return {
#                 init: function (viz_id = null) {
#
#                     // console.log('basic init')
#                     if (viz_id == null){
#                         viz_id = "viz_" + Math.round(Math.random() * 10000000)
#                     }
#                     const div = d3.select('#basic').attr('id', viz_id),
#                         div_parent = d3.select('#' + viz_id).node().parentNode
#
#                     // Link to CSS file
#                     d3.select(div_parent).insert('link')
#                         .attr('rel', 'stylesheet')
#                         .attr('type', 'text/css')
#                         .attr('href', ecco_url + 'html/styles.css')
#
#                     return viz_id
#                 }
#             }
#         }, function (err) {console.log(err);}
#     )
#     // console.log('after defining basic')
#
# </script>
# <div id="basic"></div>

# %% [markdown]
# By shrinking the saliency highlights down to small thumbnail, we can see the attributions for all the output tokens at the same time:

# %%
jsViz(outputToSaliency(output), {'type': 'paragraph-minimap', 'isDev': 0})
# Out:
#     <link rel='stylesheet' href='__hs_placeholder'>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3_.js'></script>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3-scale-chromatic.v1.min.js'></script>
#     <a style='display:none' class='no-js' href='https://roadtolarissa.com/colab/fpld4dp8lo/2021-07-saliency-viz/paragraph-minimap/watch-files.js?6'>Click to authenticate</a>
#     <div class='container'></div>
#
#     <script>window.python_data = {'tokens': [{'token': 'The', 'token_id': 464, 'type': 'input', 'value': '0.005583909', 'position': 0}, {'token': ' race', 'token_id': 3234, 'type': 'input', 'value': '0.0072955657', 'position': 1}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.0067726225', 'position': 2}, {'token': ' Mars', 'token_id': 8706, 'type': 'input', 'value': '0.009858682', 'position': 3}, {'token': ' involves', 'token_id': 9018, 'type': 'input', 'value': '0.0059526884', 'position': 4}, {'token': ' competition', 'token_id': 5449, 'type': 'input', 'value': '0.005451667', 'position': 5}, {'token': ' between', 'token_id': 1022
# %% [markdown]
# Comparing thumbnails across output tokens is still tricky. Instead of preserving input token position, we can squeeze each token down to a 2px wide bar to move input tokens closer to each other across tokens.
#
# This visualization also allows for direction comparisons of attributions between two output tokens with a diverging color scale — try clicking on an output token and hovering over another.

# %%
jsViz(outputToSaliency(output), {'type': 'paragraph-tall-heatmap', 'isDev': 0})
# Out:
#     <link rel='stylesheet' href='__hs_placeholder'>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3_.js'></script>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3-scale-chromatic.v1.min.js'></script>
#     <a style='display:none' class='no-js' href='https://roadtolarissa.com/colab/fpld4dp8lo/2021-07-saliency-viz/paragraph-tall-heatmap/watch-files.js?6'>Click to authenticate</a>
#     <div class='container'></div>
#
#     <script>window.python_data = {'tokens': [{'token': 'The', 'token_id': 464, 'type': 'input', 'value': '0.005583909', 'position': 0}, {'token': ' race', 'token_id': 3234, 'type': 'input', 'value': '0.0072955657', 'position': 1}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.0067726225', 'position': 2}, {'token': ' Mars', 'token_id': 8706, 'type': 'input', 'value': '0.009858682', 'position': 3}, {'token': ' involves', 'token_id': 9018, 'type': 'input', 'value': '0.0059526884', 'position': 4}, {'token': ' competition', 'token_id': 5449, 'type': 'input', 'value': '0.005451667', 'position': 5}, {'token': ' between', 'token_id': 1022, 'type': 'input', 'value': '0.003428069', 'position': 6}, {'token': ' manufacturers', 'token_id': 11372, 'type': 'input', 'value': '0.009710506', 'position': 7}, {'token': ' and', 'token_id': 290, 'type': 'input', 'value': '0.0033762685', 'position': 8}, {'token': ' nations', 'token_id': 7027, 'type': 'input', 'value': '0.00590676', 'position': 9}, {'token': '.', 'token_id': 13, 'type': 'input', 'value': '0.0046732784', 'position': 10}, {'token': ' NASA', 'token_id': 8884, 'type': 'input', 'value': '0.0076050228', 'position': 11}, {'token': ' has', 'token_id': 468, 'type': 'input', 'value': '0.0028842087', 'position': 12}, {'token': ' dem', 'token_id': 1357, 'type': 'input', 'value': '0.008154767', 'position': 13}, {'token': 'urred', 'token_id': 12808, 'type': 'input', 'value': '0.01085641', 'position': 14}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.002481836', 'position': 15}, {'token': ' a', 'token_id': 257, 'type': 'input', 'value': '0.0023692993', 'position': 16}, {'token': ' potential', 'token_id': 2785, 'type': 'input', 'value': '0.00356666', 'position': 17}, {'token': ' rivalry', 'token_id': 26390, 'type': 'input', 'value': '0.01088904', 'position': 18}, {'token': ' with', 'token_id': 351, 'type': 'input', 'value': '0.0020398097', 'position': 19}, {'token': ' SpaceX', 'token_id': 26549, 'type': 'input', 'value': '0.014180644', 'position': 20}, {'token': ' or', 'token_id': 393, 'type': 'input', 'value': '0.0037552516', 'position': 21}, {'token': ' other', 'token_id': 584, 'type': 'input', 'value': '0.0011302567', 'position': 22}, {'token': ' manufacturers', 'token_id': 11372, 'type': 'input', 'value': '0.0044149077', 'position': 23}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.0023303197', 'position': 24}, {'token': ' any', 'token_id': 597, 'type': 'input', 'value': '0.00198979', 'position': 25}, {'token': ' possible', 'token_id': 1744, 'type': 'input', 'value': '0.0030296466', 'position': 26}, {'token': ' race', 'token_id': 3234, 'type': 'input', 'value': '0.005667755', 'position': 27}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.0037582568', 'position': 28}, {'token': ' be', 'token_id': 307, 'type': 'input', 'value': '0.0037956457', 'position': 29}, {'token': ' first', 'token_id': 717, 'type': 'input', 'value': '0.006788166', 'position': 30}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.0016655113', 'position': 31}, {'token': ' Mars', 'token_id': 8706, 'type': 'input', 'value': '0.0047783204', 'position': 32}, {'token': '.', 'token_id': 13, 'type': 'input', 'value': '0.003833974', 'position': 33}, {'token': ' It', 'token_id': 632, 'type': 'input', 'value': '0.0023117755', 'position': 34}, {'token': ' instead', 'token_id': 2427, 'type': 'input', 'value': '0.0035509418', 'position': 35}, {'token': ' sees', 'token_id': 7224, 'type': 'input', 'value': '0.003918272', 'position': 36}, {'token': ' synerg', 'token_id': 39209, 'type': 'input', 'value': '0.007813388', 'position': 37}, {'token': 'ies', 'token_id': 444, 'type': 'input', 'value': '0.0015455853', 'position': 38}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.0016177772', 'position': 39}, {'token': ' possible', 'token_id': 1744, 'type': 'input', 'value': '0.0024391778', 'position': 40}, {'token': ' cooperation', 'token_id': 11113,  ...

# %% [markdown]
# Rearranging the charts and making the bars a bit thinner, we can also compare attributions across continuations.
#
# If the model answers a question a different way is it looking at different input text? This vis could also be used to compare saliency methods.

# %%
outputs = [
  output, 
  lm.generate(text, generate=30, do_sample=True),
  lm.generate(text, generate=30, do_sample=True),
]

# %%
jsViz(list(map(outputToSaliency, outputs)), {'type': 'paragraph-tall-multiple', 'isDev': 0})
# Out:
#     <link rel='stylesheet' href='__hs_placeholder'>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3_.js'></script>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3-scale-chromatic.v1.min.js'></script>
#     <a style='display:none' class='no-js' href='https://roadtolarissa.com/colab/fpld4dp8lo/2021-07-saliency-viz/paragraph-tall-multiple/watch-files.js?6'>Click to authenticate</a>
#     <div class='container'></div>
#
 'type': 'input', 'value': '0.003833974', 'position': 33}, {'token': ' It', 'token_id': 632, 'type': 'input', 'value': '0.0023117755', 'position': 34}, {'token': ' instead', 'token_id': 2427, 'type': 'input', 'value': '0.0035509418', 'position': 35}, {'token': ' sees', 'token_id': 7224, 'type': 'input', 'value': '0.003918272', 'position': 36}, {'token': ' synerg', 'token_id': 39209, 'type': 'input', 'value': '0.007813388', 'position': 37}, {'token': 'ies', 'token_id': 444, 'type': 'input', 'value': '0.0015455853', 'position': 38}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.0016177772', 'position': 39}, {'token': ' possible', 'token_id': 1744, 'type': 'input', 'value': '0.0024391778', 'position': 40}, {'token': ' cooperation', 'token_id': 11113, ...

# %% [markdown]
# More than ~30 output tokens take up too much vertical space.
#
# Shrinking the heights of the bars this time to squeze in more output tokens, we're left with a heatmap:

# %%
longOutputs = [
  lm.generate(text, generate=100, do_sample=True),
  lm.generate(text, generate=100, do_sample=True),
  lm.generate(text, generate=100, do_sample=True),
]

# %%
jsViz(list(map(outputToSaliency, longOutputs)), {'isDev': 0, 'type': 'paragraph-long-output'})
# Out:
#     <link rel='stylesheet' href='__hs_placeholder'>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3_.js'></script>
#     <script src='https://pair.withgoogle.com/explorables/third_party/d3-scale-chromatic.v1.min.js'></script>
#     <a style='display:none' class='no-js' href='https://roadtolarissa.com/colab/fpld4dp8lo/2021-07-saliency-viz/paragraph-long-output/watch-files.js?6'>Click to authenticate</a>
#     <div class='container'></div>
#
#     <script>window.python_data = [{'tokens': [{'token': 'The', 'token_id': 464, 'type': 'input', 'value': '0.0057248496', 'position': 0}, {'token': ' race', 'token_id': 3234, 'type': 'input', 'value': '0.0074360943', 'position': 1}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.0056659533', 'position': 2}, {'token': ' Mars', 'token_id': 8706, 'type': 'input', 'value': '0.010234535', 'position': 3}, {'token': ' involves', 'token_id': 9018, 'type': 'input', 'value': '0.0059048883', 'position': 4}, {'token': ' competition', 'token_id': 5449, 'type': 'input', 'value': '0.0053683766', 'position': 5}, {'token': ' between', 'token_id': 1022, 'type': 'input', 'value': '0.0033883823', 'position': 6}, {'token': ' manufacturers', 'token_id': 11372, 'type': 'input', 'value': '0.009668397', 'position': 7}, {'token': ' and', 'token_id': 290, 'type': 'input', 'value': '0.0028619033', 'position': 8}, {'token': ' nations', 'token_id': 7027, 'type': 'input', 'value': '0.0057892753', 'position': 9}, {'token': '.', 'token_id': 13, 'type': 'input', 'value': '0.005130531', 'position': 10}, {'token': ' NASA', 'token_id': 8884, 'type': 'input', 'value': '0.007113896', 'position': 11}, {'token': ' has', 'token_id': 468, 'type': 'input', 'value': '0.00279804', 'position': 12}, {'token': ' dem', 'token_id': 1357, 'type': 'input', 'value': '0.007915475', 'position': 13}, {'token': 'urred', 'token_id': 12808, 'type': 'input', 'value': '0.010791157', 'position': 14}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.0023677808', 'position': 15}, {'token': ' a', 'token_id': 257, 'type': 'input', 'value': '0.0021825603', 'position': 16}, {'token': ' potential', 'token_id': 2785, 'type': 'input', 'value': '0.0035857665', 'position': 17}, {'token': ' rivalry', 'token_id': 26390, 'type': 'input', 'value': '0.010885395', 'position': 18}, {'token': ' with', 'token_id': 351, 'type': 'input', 'value': '0.002017242', 'position': 19}, {'token': ' SpaceX', 'token_id': 26549, 'type': 'input', 'value': '0.012738008', 'position': 20}, {'token': ' or', 'token_id': 393, 'type': 'input', 'value': '0.0035700959', 'position': 21}, {'token': ' other', 'token_id': 584, 'type': 'input', 'value': '0.0011425077', 'position': 22}, {'token': ' manufacturers', 'token_id': 11372, 'type': 'input', 'value': '0.004373507', 'position': 23}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.0022191901', 'position': 24}, {'token': ' any', 'token_id': 597, 'type': 'input', 'value': '0.0020279656', 'position': 25}, {'token': ' possible', 'token_id': 1744, 'type': 'input', 'value': '0.0030510868', 'position': 26}, {'token': ' race', 'token_id': 3234, 'type': 'input', 'value': '0.005953778', 'position': 27}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.003638254', 'position': 28}, {'token': ' be', 'token_id': 307, 'type': 'input', 'value': '0.003881234', 'position': 29}, {'token': ' first', 'token_id': 717, 'type': 'input', 'value': '0.0071014385', 'position': 30}, {'token': ' to', 'token_id': 284, 'type': 'input', 'value': '0.0015021509', 'position': 31}, {'token': ' Mars', 'token_id': 8706, 'type': 'input', 'value': '0.004783056', 'position': 32}, {'token': '.', 'token_id': 13, 'type': 'input', 'value': '0.003984063', 'position': 33}, {'token': ' It', 'token_id': 632, 'type': 'input', 'value': '0.0022240637', 'position': 34}, {'token': ' instead', 'token_id': 2427, 'type': 'input', 'value': '0.0035166864', 'position': 35}, {'token': ' sees', 'token_id': 7224, 'type': 'input', 'value': '0.0039120223', 'position': 36}, {'token': ' synerg', 'token_id': 39209, 'type': 'input', 'value': '0.007885078', 'position': 37}, {'token': 'ies', 'token_id': 444, 'type': 'input', 'value': '0.0015597753', 'position': 38}, {'token': ' in', 'token_id': 287, 'type': 'input', 'value': '0.0016252622', 'position': 39}, {'token': ' possible', 'token_id': 1744, 'type': 'input', 'value': '0.0024069487', 'position': 40}, {'token': ' cooperation', 'token_id': 1 ...

# %% [markdown]
# Other ideas:
#
# - Input instead of output focused
#   - With a fixed token width and a short continuation, you could show output attributions above every input token
#   - Clicking could show how attributions are different between two input tokens
# - Non-linear positioning of tokens
#   - UMAP/PCA
#   - Color could encode sentence position; x/y could show attribution.
# - Only show "interesting" interactions
#   - Remove stop words / low values
#   - Shift-click to expand a row of the heat map
# - Can we pull anything else out of attribution methods beside scalars?
# - Would normalizing relative position be useful?
# - Interactions between tokens / perturbation
